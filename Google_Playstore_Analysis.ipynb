# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
lst=[1,4,5,5,6]
np.array(lst)
pd.Series(lst)
pd.DataFrame([lst,lst,lst],columns=['A','B','C','D','E'])
# Out:
#    A  B  C  D  E
# 0  1  4  5  5  6
# 1  1  4  5  5  6
# 2  1  4  5  5  6

# %%
data=pd.read_csv("googleplaystore.csv")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
for i in data.columns:
    print(i)
# Out:
# App
# Category
# Rating
# Reviews
# Size
# Installs
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver

# %%
data['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
for i in data.columns:
    print(data[i][0])
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# ART_AND_DESIGN
# 4.1
# 159
# 19M
# 10,000+
# Free
# 0
# Everyone
# Art & Design
# January 7, 2018
# 1.0.0
# 4.0.3 and up

# %% [markdown]
# # Removing Null Values

# %%
data.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # Using Dropna method

# %%
df=data.dropna()

# %%
10841-9360
#with_null_values-without null values
# Out:
# 1481

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# # Finding Average Rating

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9360, dtype: float64

# %%
int(sum(df['Rating']))/9360    #average rating
# Out:
# 4.191773504273504

# %% [markdown]
# # How many apps are there with rating 5?

# %%
c=0
for i in df['Rating']:
    if(i==5.0):
        c+=1
print("There are",c,"applications with rating 5")
# Out:
# There are 274 applications with rating 5

# %% [markdown]
# # How many apps are there with rating between 4.0 to 4.5

# %%
d=0
for i in df['Rating']:
    if (i>=4.0 and i<=4.5):
        d+=1
        
print("There are",d,"applications with rating between 4 to 4.5")

# %% [markdown]
# # Working with Reviews Column

# %%
#Avergae Review
s=0
for i in df['Reviews']:
    s+=int(i)
    
print(int(s/len(data['Reviews'])))
# Out:
# 444107

# %% [markdown]
# # Working with Categorical value

# %%
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10834                 FAMILY
# 10836                 FAMILY
# 10837                 FAMILY
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 9360, dtype: object

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
for i in df['Category'].unique():
    print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION

# %% [markdown]
# # Total Number of Categories

# %%
print("There are " ,len(df['Category'].unique())," Categories")
# Out:
# There are  33  Categories

# %% [markdown]
# # How many applications are there for ART_AND_DESGIN?

# %%
c=0
for i in df['Category']:
    if(i=='ART_AND_DESIGN'):
        c+=1
        
print("There are ",c,"Applications for ART_AND_DESIGN")
# Out:
# There are  61 Applications for ART_AND_DESIGN

# %% [markdown]
# # Working with Type Column

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
free=0
for i in df['Type']:
    if(i=='Free'):
        free+=1
        
print("There are ",free," free Applications ")
# Out:
# There are  8715  free Applications

# %%
paid=0
for i in df['Type']:
    if(i=='Paid'):
        paid+=1
        
print("There are ",paid," Paid Applications")
# Out:
# There are  645  Paid Applications

# %% [markdown]
# # Percentage of categories

# %%
free/(free+paid)*100
# Out:
# 93.10897435897436

# %% [markdown]
# # Working with Content writing column

# %%
for i in df['Content Rating']:
    print(i)
# Out:
# Everyone
# Everyone
# Everyone
# Teen
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Teen
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone 10+
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Teen
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Teen
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone 10+
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# ...

# %% [markdown]
# # Data-analysis - Automatic Categorical variables

# %% [markdown]
# Total Number of apps in each category

# %%
categories={}
for name in df['Category'].unique():
    count=0
    for i in df['Category']:
        if(i==name):
            count+=1
    categories[name]=count

# %%
categories
# Out:
# {'ART_AND_DESIGN': 61,
#  'AUTO_AND_VEHICLES': 73,
#  'BEAUTY': 42,
#  'BOOKS_AND_REFERENCE': 178,
#  'BUSINESS': 303,
#  'COMICS': 58,
#  'COMMUNICATION': 328,
#  'DATING': 195,
#  'EDUCATION': 155,
#  'ENTERTAINMENT': 149,
#  'EVENTS': 45,
#  'FINANCE': 323,
#  'FOOD_AND_DRINK': 109,
#  'HEALTH_AND_FITNESS': 297,
#  'HOUSE_AND_HOME': 76,
#  'LIBRARIES_AND_DEMO': 64,
#  'LIFESTYLE': 314,
#  'GAME': 1097,
#  'FAMILY': 1746,
#  'MEDICAL': 350,
#  'SOCIAL': 259,
#  'SHOPPING': 238,
#  'PHOTOGRAPHY': 317,
#  'SPORTS': 319,
#  'TRAVEL_AND_LOCAL': 226,
#  'TOOLS': 733,
#  'PERSONALIZATION': 312,
#  'PRODUCTIVITY': 351,
#  'PARENTING': 50,
#  'WEATHER': 75,
#  'VIDEO_PLAYERS': 160,
#  'NEWS_AND_MAGAZINES': 233,
#  'MAPS_AND_NAVIGATION': 124}

# %%
categories['ART_AND_DESIGN']
# Out:
# 61

# %%
for i in df['Category'].unique():
    print(i,categories[i])
# Out:
# ART_AND_DESIGN 61
# AUTO_AND_VEHICLES 73
# BEAUTY 42
# BOOKS_AND_REFERENCE 178
# BUSINESS 303
# COMICS 58
# COMMUNICATION 328
# DATING 195
# EDUCATION 155
# ENTERTAINMENT 149
# EVENTS 45
# FINANCE 323
# FOOD_AND_DRINK 109
# HEALTH_AND_FITNESS 297
# HOUSE_AND_HOME 76
# LIBRARIES_AND_DEMO 64
# LIFESTYLE 314
# GAME 1097
# FAMILY 1746
# MEDICAL 350
# SOCIAL 259
# SHOPPING 238
# PHOTOGRAPHY 317
# SPORTS 319
# TRAVEL_AND_LOCAL 226
# TOOLS 733
# PERSONALIZATION 312
# PRODUCTIVITY 351
# PARENTING 50
# WEATHER 75
# VIDEO_PLAYERS 160
# NEWS_AND_MAGAZINES 233
# MAPS_AND_NAVIGATION 124

# %% [markdown]
# # Total number of apps in each type

# %%
types={}
for name in df['Type'].unique():
    count=0
    for i in df['Type']:
        if(i==name):
            count+=1
    types[name]=count
    
print(types)
# Out:
# {'Free': 8715, 'Paid': 645}

# %% [markdown]
# # Total number of apps in each Content Rating

# %%
contents={}
for name in df['Content Rating'].unique():
    count=0
    for i in df['Content Rating']:
        if(i==name):
            count+=1
    contents[name]=count
    
print(contents)
# Out:
# {'Everyone': 7414, 'Teen': 1084, 'Everyone 10+': 397, 'Mature 17+': 461, 'Adults only 18+': 3, 'Unrated': 1}

# %% [markdown]
# # Handling the Null Values

# %%
from sklearn.impute import SimpleImputer

# %%
impute=SimpleImputer(missing_values=np.nan,strategy='mean')
impute.fit(df.iloc[:,2:3].values)
df.iloc[:,2:3]=impute.transform(df.iloc[:,2:3].values)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64
